# %% [markdown]
# # GDP ANALYSIS

# %% [markdown]
# ### Scatter - Developing vs Developed

# %%
from GDP_functions import medal_vs_gdp_scatter
plt = medal_vs_gdp_scatter('USA','USA','total',False)

# %%
from GDP_functions import medal_vs_gdp_scatter
plt = medal_vs_gdp_scatter('JAM','JAM','total',False)

# %% [markdown]
# ### Scatter - rate of changes

# %%
from GDP_functions import plot_rate
plt = plot_rate()

# %% [markdown]
# # Women in Olympics

# %%
from gender_parity import plot_us_women_win_ratio
plot_us_women_win_ratio()

# %%
from gender_parity import plot_sex_ratio_year_wise
plot_sex_ratio_year_wise()

# %%
from gender_parity import  plot_country_sex_ratio
plot_country_sex_ratio("KSA")

# %%
from gender_parity import plot_global_sex_ratio
plot_global_sex_ratio()
# Out:
# file://C:/Users/tawaa/AppData/Local/Temp/tmphkfnsbbw.html

# %% [markdown]
# # Tokyo 2020 Predictions

# %%
from prediction_plots import stacked_bar_plot
stacked_bar_plot()

# %%
from prediction_plots import medal_trends_1
medal_trends_1()

# %%
from prediction_plots import medal_trends_2
medal_trends_2()

# %%
from prediction_plots import world_map
world_map()
# Out:
# ['./dat/country_medals.html']
